# %% [markdown]
# # Advanced visualization

# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user'

# %%
movies = pd.read_csv(r"D:\October\13-10-23\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\Movie-Rating.csv")

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.shape
# Out:
# (559, 6)

# %%
len(movies)
# Out:
# 559

# %%
movies.columns = ['Film','Genre','Critical Rating','Audience Rating', 'Budgetmillions','Year']

# %%
movies.tail()    # removes noise characters in columns
# Out:
#                 Film     Genre  Critical Rating  Audience Rating  \
# 554    Your Highness    Comedy               26               36
# 555  Youth in Revolt    Comedy               68               52
# 556           Zodiac  Thriller               89               73
# 557      Zombieland     Action               90               87
# 558        Zookeeper    Comedy               14               42
#
#      Budgetmillions  Year
# 554              50  2011
# 555              18  2009
# 556              65  2007
# 557              24  2009
# 558              80  2011

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   Critical Rating  559 non-null    int64
#  3   Audience Rating  559 non-null    int64
#  4   Budgetmillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film          # Same the above code
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.describe()
# Out:
#        Critical Rating  Audience Rating  Budgetmillions         Year
# count       559.000000       559.000000      559.000000   559.000000
# mean         47.309481        58.744186       50.236136  2009.152057
# std          26.413091        16.826887       48.731817     1.362632
# min           0.000000         0.000000        0.000000  2007.000000
# 25%          25.000000        47.000000       20.000000  2008.000000
# 50%          46.000000        58.000000       35.000000  2009.000000
# 75%          70.000000        72.000000       65.000000  2010.000000
# max          97.000000        96.000000      300.000000  2011.000000

# %%
movies.Year = movies.Year.astype('category')

# %%
movies.describe()
# Out:
#        Critical Rating  Audience Rating  Budgetmillions
# count       559.000000       559.000000      559.000000
# mean         47.309481        58.744186       50.236136
# std          26.413091        16.826887       48.731817
# min           0.000000         0.000000        0.000000
# 25%          25.000000        47.000000       20.000000
# 50%          46.000000        58.000000       35.000000
# 75%          70.000000        72.000000       65.000000
# max          97.000000        96.000000      300.000000

# %%
movies['Film']= movies['Film'].astype('category')
movies.Genre = movies.Genre.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   Critical Rating  559 non-null    int64
#  3   Audience Rating  559 non-null    int64
#  4   Budgetmillions   559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre.cat.categories   # Particular catergory of the attribute
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %% [markdown]
# # Lets start Advanced visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data=movies, x= 'Critical Rating', y = 'Audience Rating') # join uni and bivariabte graph

# %%
j = sns.jointplot(data=movies, x= 'Critical Rating', y = 'Audience Rating', kind = 'hex')

# %%
j = sns.jointplot(data=movies, x= 'Critical Rating', y = 'Audience Rating', kind = 'reg')

# %%
m1 = sns.distplot(movies['Audience Rating'])

# %%
sns.set_style('dark')

# %%
m2 = sns.displot(movies['Audience Rating'], bins = 15)

# %%
 m3 = plt.hist(movies['Audience Rating'], bins=20)
    # normal distribution called bell curve

# %%
sns.set_style('darkgrid')

# %%
n1 = plt.hist(movies['Critical Rating'], bins= 15)  #uniform distribution

# %%
from matplotlib import pyplot as plt 
plt.hist(movies.Budgetmillions)
# Out:
# (array([237., 162.,  75.,  28.,  17.,  20.,  13.,   3.,   3.,   1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movies[movies.Genre == 'Drama'].Budgetmillions)   # category of drama with budgetmillion
# Out:
# (array([25., 40., 18.,  8.,  6.,  2.,  1.,  0.,  0.,  1.]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.]),
#  <BarContainer object of 10 artists>)

# %%
sns.set_style('white')

plt.hist(movies[movies.Genre == 'Action'].Budgetmillions, bins = 20)
plt.hist(movies[movies.Genre == 'Thriller'].Budgetmillions, bins = 20)
plt.hist(movies[movies.Genre == 'Drama'].Budgetmillions, bins = 20)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist([movies[movies.Genre == 'Action'].Budgetmillions,\
          movies[movies.Genre == 'Drama'].Budgetmillions, \
          movies[movies.Genre == 'Thriller'].Budgetmillions, \
          movies[movies.Genre == 'Comedy'].Budgetmillions],
         bins = 20, stacked = True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:   # we use same function 1000and aboce cat.
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data = movies, x = 'Critical Rating', y = 'Audience Rating', fit_reg = False)

# %%
vis1 = sns.lmplot(data = movies, x = 'Critical Rating', y = 'Audience Rating', fit_reg = False, hue = 'Genre')

# %%
vis1 = sns.lmplot(data = movies, x = 'Critical Rating', y = 'Audience Rating', fit_reg = False,\
                   hue = 'Genre', height = 10, aspect=1)  # in seaborn we use height instead of size latest version

# %% [markdown]
# # Kernal density plot

# %%
movies.head()
# Out:
#                     Film      Genre  Critical Rating  Audience Rating  \
# 0  (500) Days of Summer      Comedy               87               81
# 1            10,000 B.C.  Adventure                9               44
# 2             12 Rounds      Action               30               52
# 3              127 Hours  Adventure               93               84
# 4              17 Again      Comedy               55               70
#
#    Budgetmillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
k1 = sns.kdeplot(data=movies, x='Audience Rating', y='Critical Rating')

# %%
k2 = sns.kdeplot(data=movies,x='Critical Rating',y='Audience Rating', shade = True,shade_lowest=False,cmap='Reds')

# %%
movies['Critical Rating']
# Out:
# 0      87
# 1       9
# 2      30
# 3      93
# 4      55
#        ..
# 554    26
# 555    68
# 556    89
# 557    90
# 558    14
# Name: Critical Rating, Length: 559, dtype: int64

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies['Audience Rating']
# Out:
# 0      81
# 1      44
# 2      52
# 3      84
# 4      70
#        ..
# 554    36
# 555    52
# 556    73
# 557    87
# 558    42
# Name: Audience Rating, Length: 559, dtype: int64

# %%
k2 = sns.kdeplot(data=movies,x='Critical Rating',y='Audience Rating',shade_lowest=False,cmap='Greens')

# %%
k3 = sns.kdeplot(data=movies,x='Budgetmillions',y='Audience Rating',shade_lowest=True,cmap='Reds')

# %%
k4 = sns.kdeplot(data=movies,x='Budgetmillions',y= 'Critical Rating')

# %%
f, ax = plt.subplots(1,2, figsize =(10,6)) # subplot creations

# %%
f, axes = plt.subplots(1,2, figsize =(10,6))

k1 = sns.kdeplot(data = movies, x = 'Budgetmillions', y= 'Audience Rating', ax= axes[0])
k2 = sns.kdeplot(data = movies, x = 'Budgetmillions', y= 'Critical Rating', ax= axes[1])

# %%
axes
# Out:
# array([<Axes: xlabel='Budgetmillions', ylabel='Audience Rating'>,
#        <Axes: xlabel='Budgetmillions', ylabel='Critical Rating'>],
#       dtype=object)

# %%
b1 = sns.boxplot(data = movies, x= 'Genre', y = 'Critical Rating')
sns.set_style('darkgrid')

# %%
# violin plot is same as box plot  but density only show like kde
v1  = sns.violinplot(data = movies, x= 'Genre', y = 'Critical Rating')

# %%
w1 = sns.boxplot(data=movies[movies.Genre == 'Drama'], x='Year', y = 'Critical Rating')

# %%
w1 = sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y = 'Critical Rating')

# %%
# Facet Grid plot like subplot
g = sns.FacetGrid(movies, row= 'Genre', col= 'Year', hue = 'Genre')
sns.set_style('white')

# %%
 g1= plt.scatter(movies['Critical Rating'],movies['Audience Rating'])

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'Critical Rating', 'Audience Rating' ) #scatterplots are mapped in facetgrid

# %%
 g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist ,'Budgetmillions') #scatterplots are mapped in facetgrid

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'Critical Rating', 'Audience Rating',**kws ) #scatterplots are mapped in facetgrid

# %%
# Building dashboards (dashboard - combination of chats)

sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (10,6))

k1 = sns.kdeplot(data=movies,x= 'Budgetmillions',y='Audience Rating',ax=axes[0,0])
k2 = sns.kdeplot(data=movies,x='Budgetmillions',y='Critical Rating',ax = axes[0,1])

k1.set(xlim=(-20,250))
k2.set(xlim=(-20,250))

z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'Critical Rating', ax=axes[1,0])


k4b = sns.kdeplot(data= movies,x='Critical Rating',y='Audience Rating',cmap='Reds',ax = axes[1,1])

plt.show()

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (10,6))
# plot1
k1 = sns.kdeplot(data=movies,x= 'Budgetmillions',y='Audience Rating',\
                 shade = True, shade_lowest=True,cmap = 'gist_earth_r',ax=axes[0,0])
k1 = sns.kdeplot(data=movies,x= 'Budgetmillions',y='Audience Rating',\
                 shade = True, shade_lowest=True,cmap = 'cool',ax=axes[0,0])

#plot2
k2 = sns.kdeplot(data=movies,x='Budgetmillions',y='Critical Rating',\
                 shade = True, shade_lowest=True,cmap = 'copper_r',ax = axes[0,1])


k2 = sns.kdeplot(data=movies,x='Budgetmillions',y='Critical Rating',\
                 shade = True, shade_lowest=True,cmap = 'cool',ax = axes[0,1])

k1.set(xlim=(-20,250))
k2.set(xlim=(-20,250))
#plot3
z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'Critical Rating', ax=axes[1,0])

#plot4
k4b = sns.kdeplot(data= movies,x='Critical Rating',y='Audience Rating',\
                  shade = True,shade_lowest=False,cmap='Blues',ax = axes[1,1])
k4b = sns.kdeplot(data= movies,x='Critical Rating',y='Audience Rating',\
                  shade = True,shade_lowest=False,cmap='Reds',ax = axes[1,1])

plt.show()

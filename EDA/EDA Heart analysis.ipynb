# %% [markdown]
# # Heart Patient analysis using EDA

# %%
import pandas as pd 
import numpy as np

# %%
import os
for dirname, _, filenames in os.walk('D:/October/17-10-23/EDA/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# D:/October/17-10-23/EDA/extensive-analysis-visualization-with-python.ipynb
# D:/October/17-10-23/EDA/heart.csv

# %%
Heart = pd.read_csv(r"D:\October\17-10-23\EDA\heart.csv")

# %%
Heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
Heart.shape
# Out:
# (303, 14)

# %%
Heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
Heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
Heart.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
Heart.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
Heart.describe()  # statistical property of dataset
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
Heart['target'].nunique()   # target is a classicifation algorithm 0- absence of heart disease 1- presence of heart disease
# Out:
# 2

# %%
Heart['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
Heart['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
# visualize the target variable 
# univariate(target) so countplot (1-165,0-138) advance visualze
import matplotlib.pyplot as plt
import seaborn as sns 
import scipy.stats as st
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
f,ax = plt.subplots()
vis = sns.countplot(x='target',data=Heart, hue='target')
plt.show()

# %%
# To find how many of Heart patience are male and female
Heart.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: target, dtype: int64

# %%
# the above information 0- female,1- male
Heart['sex'].value_counts()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
vis1=sns.countplot(x='target',data=Heart,hue='sex')

# %%
vis1=sns.countplot(x='sex',data=Heart,hue='target')

# %%
ax= sns.catplot(x='target',col='sex',data=Heart,kind='count',height=5,aspect=1,)

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(y="target", hue="sex", data=Heart)
plt.show()

# %%
f,ax= plt.subplots(figsize=(8,6))
ax= sns.countplot(x='target',data=Heart,palette='Set3')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", data=Heart, facecolor=(0, 0, 0, 0), linewidth=5, edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", data=Heart, hue='fbs')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.set_style(style='darkgrid')
ax = sns.countplot(x="target", data=Heart,hue='exang')
plt.show()

# %%
correlation = Heart.corr()

# %%
correlation
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
correlation['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %%
# dv is target so we corr with othervariables
# -ve corr varibales not consider ,+ve corr(0 to 1) but no variable as strong +ve and strong -ve corr
# so nearly +ve corr 'cp','thalach' so we consider these two variables
Heart['cp'].nunique()  # unique variable counting
# Out:
# 4

# %%
Heart['cp'].unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
Heart['cp'].value_counts()
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
# cp-chest pain its 4 (0,1,2,3) so its categorical variable than ipdi eda tech.use pani separate painrukanga
Heart.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: target, dtype: int64

# %%
f,ax= plt.subplots(figsize=(8,6))
vis2= sns.countplot(x='cp',data=Heart,palette=('green','red','blue','orange'))

# %%
f,ax= plt.subplots(figsize=(8,6))
vis2= sns.countplot(x='cp',data=Heart,hue='target')
plt.show()

# %%
ax = sns.catplot(x="target", col="cp", data=Heart, kind="count", height=8, aspect=1)

# %%
# another variable 'thalach'
Heart['thalach'].nunique()
# Out:
# 91

# %%
# 91 unique variable so its numerical data so we go for visualize using distplot
f,ax= plt.subplots(figsize=(6,6))
ax=sns.distplot(Heart['thalach'],bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = Heart['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.distplot(x, bins=10)
plt.show()

# %%
f,ax= plt.subplots(figsize=(6,6))
ax=sns.distplot(Heart['thalach'],bins=10,vertical=True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = Heart['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8,6))
x = Heart['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x, shade=True,color='red')
plt.show()

# %%
f,ax= plt.subplots(figsize=(6,6))
ax=sns.distplot(Heart['thalach'],bins=10,rug=True,kde=False)
plt.show()           #histogram using distplot

# %%
plt.hist(Heart['thalach'],bins=10)
# Out:
# (array([ 1.,  6., 11., 26., 35., 53., 77., 63., 26.,  5.]),
#  array([ 71. ,  84.1,  97.2, 110.3, 123.4, 136.5, 149.6, 162.7, 175.8,
#         188.9, 202. ]),
#  <BarContainer object of 10 artists>)

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="target", y="thalach", data=Heart,palette=('red','green'))
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="target", y="thalach", data=Heart,palette=('red','green'),jitter=0.01)
plt.show()

# %%
# we can analyse target=1 heart patiend has high heart rate(thalach) compare to target=0
# we can use boxplot 
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x="target", y="thalach", data=Heart,palette=('red','green'))
plt.show()

# %%
#see the above graph avarage of heart disease patient(target=1) has higher heart rate (thalach) compare to target=0

# %%
# very important to find the pattern and relationship of the dataset
# we use heat map and pairplot for these

# %%
plt.figure(figsize=(12,8))
plt.title('Correlation Heatmap of Heart Disease Dataset')
a= sns.heatmap(correlation,square=True,annot=True,fmt='.2f',linecolor='white')
a.set_xticklabels(a.get_xticklabels(), rotation=90)
a.set_yticklabels(a.get_yticklabels(), rotation=30)           
plt.show()

# %% [markdown]
# #From the above correlation heat map, we can conclude that :-
#
# target and cp variable are mildly positively correlated (correlation coefficient = 0.43).
#
# target and thalach variable are also mildly positively correlated (correlation coefficient = 0.42).
#
# target and slope variable are weakly positively correlated (correlation coefficient = 0.35).
#
# target and exang variable are mildly negatively correlated (correlation coefficient = -0.44).
#
# target and oldpeak variable are also mildly negatively correlated (correlation coefficient = -0.43).
#
# target and ca variable are weakly negatively correlated (correlation coefficient = -0.39).
#
# target and thal variable are also waekly negatively correlated (correlation coefficient = -0.34).

# %%
# these variables are numerical variables
num_var = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target' ]
sns.pairplot(Heart[num_var], kind='scatter', diag_kind='hist')
plt.show()

# %%
Heart['age'].nunique()
# Out:
# 41

# %%
Heart['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f,ax= plt.subplots(figsize=(8,6))
vis3= sns.distplot(Heart['age'],bins=10)
plt.show()

# %%
f,ax= plt.subplots(figsize=(8,6))
vis4= sns.stripplot(x='target',y='age',data=Heart,palette=('blue','orange'))
plt.show()
sns.set_style(style='darkgrid')

# %%
f,ax= plt.subplots(figsize=(8,6))
ax= sns.boxplot(x='target',y='age',data=Heart,palette=('orange','green'))
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.scatterplot(x="age", y="trestbps", data=Heart)
plt.show()

# %%
ax = sns.lmplot(x="age", y="trestbps", data=Heart)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.scatterplot(x="age", y="chol", data=Heart)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="age", y="chol", data=Heart)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.scatterplot(x="chol", y="thalach", data=Heart)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="chol", y="thalach", data=Heart)
plt.show()

# %% [markdown]
# We can write an assert statement to verify this.
#
# We can use an assert statement to programmatically check that no missing, unexpected 0 or negative values are present.
#
# This gives us confidence that our code is running properly.

# %%
assert pd.notnull(Heart).all().all()

# %%
assert (Heart>=0).all().all()
#The above two commands do not throw any error. Hence, it is confirmed that there are no missing or negative values in the dataset.
#All the values are greater than or equal to zero.

# %%
# outlier detection
#we check numerical coloums age,chol,treatbps.oldpeak,thalach

# %%
Heart['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f,ax= plt.subplots(figsize=(8,6))
ax= sns.boxplot(x=Heart['age'])
plt.show()

# %%
Heart['chol'].describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
f,ax= plt.subplots(figsize=(8,6))
ax= sns.boxplot(x=Heart['chol'])
plt.show()

# %%
Heart['trestbps'].describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
f,ax= plt.subplots(figsize=(8,6))
ax= sns.boxplot(x=Heart['trestbps'])
plt.show()

# %%
Heart['thalach'].describe()
# Out:
# count    303.000000
# mean     149.646865
# std       22.905161
# min       71.000000
# 25%      133.500000
# 50%      153.000000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
f,ax= plt.subplots(figsize=(8,6))
ax= sns.boxplot(x=Heart['thalach'])
plt.show()

# %%
Heart['oldpeak'].describe()
# Out:
# count    303.000000
# mean       1.039604
# std        1.161075
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
f,ax= plt.subplots(figsize=(8,6))
ax= sns.boxplot(x=Heart['oldpeak'])
plt.show()
